# %%
# %pip install -U langchain langchain-google-genai langchain-community langchain-chroma chromadb python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [langchain]/6 [langgraph]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
from dotenv import load_dotenv

from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_chroma import Chroma
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
load_dotenv()

api_key = os.getenv("GOOGLE_API_KEY")

if not api_key:
    raise ValueError("❌ GOOGLE_API_KEY not found in .env")

print("✅ Gemini API Key Loaded")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       3 api_key = os.getenv("GOOGLE_API_KEY")
#       5 if not api_key:
# ----> 6     raise ValueError("❌ GOOGLE_API_KEY not found in .env")
#       8 print("✅ Gemini API Key Loaded")
#
# ValueError: ❌ GOOGLE_API_KEY not found in .env

# %%
books = pd.read_csv("books_cleaned.csv")
books["tagged_description"].to_csv("tagged_description.txt", sep="\n", index=False, header=False)

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5225  9788172235222  8172235224
# 5226  9788173031014  8173031010
# 5227  9788179921623  817992162X
# 5228  9788185300535  8185300534
# 5229  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5225                                  Mistaken Identity
# 5226                                Journey to the East
# 5227  The Monk Who Sold His Ferrari: A Fable About F...
# ...

# %%
embeddings = GoogleGenerativeAIEmbeddings(
    model="models/embedding-001",
    google_api_key=gemini_api_key,
)
print("✅ Embeddings initialized")
# Out:
# ✅ Embeddings initialized

# %%
raw_documents = TextLoader("tagged_description.txt").load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0, separator="\n")
documents = text_splitter.split_documents(raw_documents)
# Out:
# Created a chunk of size 1168, which is longer than the specified 1000
# Created a chunk of size 1214, which is longer than the specified 1000
# Created a chunk of size 1088, which is longer than the specified 1000
# Created a chunk of size 1189, which is longer than the specified 1000
# Created a chunk of size 1267, which is longer than the specified 1000
# Created a chunk of size 2010, which is longer than the specified 1000
# Created a chunk of size 1225, which is longer than the specified 1000
# Created a chunk of size 1184, which is longer than the specified 1000
# Created a chunk of size 1214, which is longer than the specified 1000
# Created a chunk of size 1191, which is longer than the specified 1000
# Created a chunk of size 1057, which is longer than the specified 1000
# Created a chunk of size 1270, which is longer than the specified 1000
# Created a chunk of size 1635, which is longer than the specified 1000
# ...

# %%
db_books = Chroma.from_documents(
    documents=documents,
    embedding=embeddings
)

print("✅ Vector database created successfully!")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/.conda/envs/BRS/lib/python3.10/site-packages/langchain_google_genai/embeddings.py:432, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     431 try:
# --> 432     result = self.client.models.embed_content(
#     433         model=self.model,
#     434         contents=batch,
#     435         config=config,
#     436     )
#     437 except ClientError as e:
#
# File ~/.conda/envs/BRS/lib/python3.10/site-packages/google/genai/models.py:4404, in Models.embed_content(self, model, contents, config)
#    4402 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4404 response = self._api_client.request(
#    4405     'post', path, request_dict, http_options
#    4406 )
# ...

# %%
def retrieve_semantic_recommendations(
        query: str,
        top_k: int = 10,
) -> pd.DataFrame:
    # Similarity search using Gemini embeddings
    recs = db_books.similarity_search(query, k=50)

    books_list = []
    for i in range(len(recs)):
        # Extracting the ISBN from the page content
        try:
            isbn = int(recs[i].page_content.strip('"').split()[0])
            books_list.append(isbn)
        except (ValueError, IndexError):
            continue

    return books[books["isbn13"].isin(books_list)].head(top_k)

# %%
results = retrieve_semantic_recommendations("A book to teach children about nature")

results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 results = retrieve_semantic_recommendations("A book to teach children about nature")
#       3 results
#
# Cell In[20], line 6, in retrieve_semantic_recommendations(query, top_k)
#       1 def retrieve_semantic_recommendations(
#       2         query: str,
#       3         top_k: int = 10,
#       4 ) -> pd.DataFrame:
#       5     # Similarity search using Gemini embeddings
# ----> 6     recs = db_books.similarity_search(query, k=50)
#       8     books_list = []
#       9     for i in range(len(recs)):
#      10         # Extracting the ISBN from the page content
#
# NameError: name 'db_books' is not defined
